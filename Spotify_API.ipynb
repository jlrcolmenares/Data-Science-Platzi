# %% [markdown]
# <a href="https://colab.research.google.com/github/joseluisramon/Data-Science-Platzi/blob/master/Spotify_API.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Proyecto Spotify API

# %% [markdown]
# ## 1. Autenticarse en la API
# La documentanción de la Spotify API indica que hay [4 métodos para autorizar](https://developer.spotify.com/documentation/general/guides/authorization-guide/#client-credentials-flow) a la aplicación.
#
# La librería Spotipy utiliza 2. Estos son los que vamos a intentar implementar:
# - Refreshable user authorization: **Authorization Code Flow**
# - Refreshable app authorization: **Client Credentials Flow**

# %% [markdown]
# ### 1.1 Clients Credentials FLow
# El flujo de "Credenciales de Cliente" utiliza eautenticación de servidor a servidor. Solo se puede acceder a los endpoints **que no acceden a la información del usuario**. La ventaja aquí es que las solicitudes a la API web realizadas sin un token de acceso tienen un límite de acción más alto.
#
# PASOS:
# 1. Hacer que tu aplicación pida autorización
# 2. Usar el token de acceso que te retornó la API para usar la Spotify API

# %% [markdown]
# ### 1.1.1. Hacer que esta notebook pida autorización
# El [tutorial sobre este método de autorización](https://developer.spotify.com/documentation/general/guides/authorization-guide/#client-credentials-flow) dice que el proceso incia con una request del tipo POST que se envía al endpoint del Account Service de Spotify.
#
# Además dice que el cuerpo(body) del post debe contener los parámetros codicado como están definiciado en la especificación OAuth 2.0.
#
# El parámetro del body es sólo uno: `grant_type = client_credentials`. Esta request también lleva información en el header: una código Authorización que está codificado en base 64 y que deberá verse como algo así: `Authorization: Basic <base64 encode client_id:client_secret>`
#
# El ejemplo que dan en la documentación es este
# ```bash
# curl -X "POST" -H "Authorization: Basic ZjM4ZjAw...WY0MzE=" -d grant_type=client_credentials https://accounts.spotify.com/api/token
# ```

# %% [markdown]
# Ahora, pasa algo. Este proceso se va a realizar utilizando la librería request de python. Y resultada que esta librería tiene desarrollado [un método de autorización OAuth 2.0](https://requests-oauthlib.readthedocs.io/en/latest/oauth2_workflow.html#backend-application-flow)
#
#
# De hecho dice: "If your provider requires that you pass **auth credentials in a Basic Auth header**" you can do this instead:
#
# ```python
# from oauthlib.oauth2 import BackendApplicationClient
# from requests.auth import HTTPBasicAuth
# auth = HTTPBasicAuth(client_id, client_secret)
# client = BackendApplicationClient(client_id=client_id)
# oauth = OAuth2Session(client=client)
# token = oauth.fetch_token(token_url='https://provider.com/oauth2/token', auth=auth)
# ```

# %%
# Tal y como vemos, para poder utilizar este método es necesario instalar 3 librería
# !pip3 install requests requests.auth
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (2.23.0)
# Collecting requests.auth
#   Downloading https://files.pythonhosted.org/packages/01/48/dcd2706d245e6709eef4f72f4ddbab239a20f3507da81456becef0401e60/requests_auth-5.1.0-py3-none-any.whl
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests) (2020.6.20)
# Installing collected packages: requests.auth
# Successfully installed requests.auth

# %%
# tambien vamos a cargar los datos de mi app de Spotify
client_id  = 'a1f9ce70491b4fbdbc386ca497a663d3'
client_secret = 'e6425613aca649ffac840e84dbd62800'

# %%
from oauthlib.oauth2 import BackendApplicationClient
from requests.auth import HTTPBasicAuth
auth = HTTPBasicAuth(client_id, client_secret)
client = BackendApplicationClient(client_id=client_id)

# %%
from requests_oauthlib import OAuth2Session
oauth = OAuth2Session(client=client)

# %%
token = oauth.fetch_token(token_url='https://accounts.spotify.com/api/token', auth=auth)
token
# Out:
# {'access_token': 'BQC_1R9biSSZHIxiPyp4yvuZk5G8s7os1TPn_SFzfnlAQVYTFgqtEjq1I_SIJPKu1KvydgbHLyQltVNPd_s',
#  'expires_at': 1600208454.2125714,
#  'expires_in': 3600,
#  'scope': [''],
#  'token_type': 'Bearer'}

# %% [markdown]
# ### 1.1.2. Usar el token de acceso que te regresó la API para hacer peticiones a la Spotify API
# Ahora que se tiene el codigo de autorizacón se puede realizar las peticiones a la API directamente
# - Documentación de la API: [link](https://developer.spotify.com/documentation/web-api/reference/artists/)
# - Documentación de Request, para saber como construir las solicitudes con headers personalizados: [link](https://requests.readthedocs.io/es/latest/user/quickstart.html#cabeceras-personalizadas)

# %% [markdown]
# **Ejemplo 1.** Buscar a todos los artistas que comiencen por "Marc"
# - Documentación de la API de Spotify. (Search API): [link](https://developer.spotify.com/documentation/web-api/reference-beta/#category-search)
#
# La API de busqueda me dice que la request es una GET que tiene dos partes:
# 1. En el Header: debe llevar el Authorization token
# 2. En el Body:
# - obligatorios
#   - q: query, palabras clave, tiene
#   - type: tipo de busqueda que esatamos haciendo
# - opcionales
#   - market: spotify presenta distintas canciones dependiendo del país en el que estés. Market sirve para seleccionar alguno específico
#   - limit: por defecto son 20, va de 1 a 50
#   - offset: el índice del primer objeto que se regresa
#   - *include_external*: Nos trae extractos de los tracks
#
# ```python
# # la librería request nos da un ejemplo de cómo funcionario esto en con un POST requests
# import json
# url = 'https://api.github.com/some/endpoint'
# payload = {'some': 'data'}
# headers = {'content-type': 'application/json'}
#
# r = requests.post(url, data=json.dumps(payload), headers=headers)
# ```

# %%
# Adaptando el ejemplo anterior
import json
import requests

# %%
url = 'https://api.spotify.com/v1/search'
payload = {'q' : 'marc', 
           'type' : 'artist'}
headers = {'Authorization': token['access_token']} 

# solo que en este caso el request tiene que ser un GET
response_search = requests.get(url, params=payload, headers=headers)
response_search
# Out:
# <Response [400]>

# %%
# El primer resultado me dice que no tengo una respuesta válida: Status_Code[400]
# Eso significa que la request que hice estuvo chimba, algo estaba mal
response_search.request.url
# Out:
# 'https://api.spotify.com/v1/search?q=marc&type=artist'

# %% [markdown]
# Así se ve una petición bien hecha: La hice utilizando la consola de la Spotify API. https://developer.spotify.com/console/
#
# `curl -X "GET" "https://api.spotify.com/v1/search?q=Marc&type=artist&market=US&limit=10&offset=0" -H "Accept: application/json" -H "Content-Type: application/json" -H "Authorization: Bearer BQAIrhms7Kg-cdTdCImXpGQLjXTxpKLx0WQ-BH-GaNGcn3qoD7Jv098CFWFYH5PiMHERkR3w63FXezdLMCdL1uWmALPrZ4gIZ2t0eKQZzQ3vpzdXH3ELWjf2-K7VsqOdNblYz9LkdzwGM57cYQ"`

# %%
# vamos a rehacer la petición 
headers = {'Accept': 'application/json',
           'Content-Type' : 'application/json',
           'Authorization' : 'Bearer '+ token['access_token']}
payload = {'q' : 'Marc',
           'type' : 'artist',
           'market' : 'US',
           'limit' : '10'}

response_search = requests.get(url,params=payload,headers=headers)
response_search
# Out:
# <Response [200]>

# %%
#ahora si
response_search.json()
# Out:
# {'artists': {'href': 'https://api.spotify.com/v1/search?query=Marc&type=artist&market=US&offset=0&limit=10',
#   'items': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3tQx1LPXbsYjE9VwN1Peaa'},
#     'followers': {'href': None, 'total': 322773},
#     'genres': ['pop', 'pop rap', 'rap'],
#     'href': 'https://api.spotify.com/v1/artists/3tQx1LPXbsYjE9VwN1Peaa',
#     'id': '3tQx1LPXbsYjE9VwN1Peaa',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/8e7706101db46f8be0226cefa7ccfa1dd86b0206',
#       'width': 640},
#      {'height': 320,
#       'url': 'https://i.scdn.co/image/e0394d55794578408c3dc461bbf83df9463a411d',
#       'width': 320},
#      {'height': 160,
#       'url': 'https://i.scdn.co/image/45c7c4de2c47a8df01e55813246f1602349fed17',
#       'width': 160}],
#     'name': 'Marc E. Bassy',
#     'popularity': 72,
#     'type': 'artist',
#     'uri': 'spotify:artist:3tQx1LPXbsYjE9VwN1Peaa'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/44mEtidu0VdRkIqO4IbkNa'},
#     'followers': {'href': None, 'total': 205384},
#     'genres': ['corridos tumbados'],
#     'href': 'https://api.spotify.com/v1/artists/44mEtidu0VdRkIqO4IbkNa',
#     'id': '44mEtidu0VdRkIqO4IbkNa',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ba0694343a4c51375d0bcfa1678b6c582c276280',
#       'width': 640},
#      {'height': 320,
#       'url': 'https://i.scdn.co/image/22027a035cc706740be8b4e9e48fbef3c37b5efd',
#       'width': 320},
#      {'height': 160,
#       'url': 'https://i.scdn.co/image/91811d451cafe0ad2f308861ef9d241337be19e6',
#       'width': 160}],
#     'name': 'Marca MP',
#     'popularity': 74,
#     'type': 'artist',
#     'uri': 'spotify:artist:44mEtidu0VdRkIqO4IbkNa'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/4wLXwxDeWQ8mtUIRPxGiD6'},
#     'followers': {'href': None, 'total': 4452780},
#     'genres': ['latin', 'latin pop', 'modern salsa', 'salsa', 'tropical'],
#     'href': 'https://api.spotify.com/v1/artists/4wLXwxDeWQ8mtUIRPxGiD6',
#     'id': '4wLXwxDeWQ8mtUIRPxGiD6',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/41b370647dcdf6ca1b561f8196ca1426da5648ac',
#       'width': 640},
#      {'height': 320,
#       'url': 'https://i.scdn.co/image/320f84b3abf6110405a2756d68d69066b6c82171',
#       'width': 320},
#      {'height': 160,
#       'url': 'https://i.scdn.co/image/11cd60c37334a0864ccf73c6fa8e1ebce48389ac',
#       'width': 160}],
#     'name': 'Marc Anthony',
#     'popularity': 80,
#     'type': 'artist',
#     'uri': 'spotify:artist:4wLXwxDeWQ8mtUIRPxGiD6'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/3tJnB0s6c3oXPq1SCCavnd'},
#     'followers': {'href': None, 'total': 3022599},
#     'genres': ['grupera',
#      'latin',
#      'latin pop',
#      'ranchera',
#      'regional mexican'],
#     'href': 'https://api.spotify.com/v1/artists/3tJnB0s6c3oXPq1SCCavnd',
#     'id': '3tJnB0s6c3oXPq1SCCavnd',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/855865af01eac6314a5582993c4bd5250e779ce8',
#       'width': 640},
#      {'height': 320,
#       'url': 'https://i.scdn.co/image/54c952aae65f8c24cbe3a8efda8f3edd48e0c4c1',
#       'width': 320},
#      {'height': 160,
#       'url': 'https://i.scdn.co/image/bbcaa91c8e43c3bd0522bbac171ad26dd87b6e4e',
#       'width': 160}],
#     'name': 'Marco Antonio Solís',
#     'popularity': 77,
#     'type': 'artist',
#     'uri': 'spotify:artist:3tJnB0s6c3oXPq1SCCavnd'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/2zF0KCQEt1O4Z9fWVUVi4T'},
#     'followers': {'href': None, 'total': 896320},
#     'genres': ['latin christian', 'latin worship'],
#     'href': 'https://api.spotify.com/v1/artists/2zF0KCQEt1O4Z9fWVUVi4T',
#     'id': '2zF0KCQEt1O4Z9fWVUVi4T',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/971c73269304b92621c4c8fe2086dd2f36451f78',
#       'width': 640},
#      {'height': 320,
#       'url': 'https://i.scdn.co/image/11fde612fc45120619a6bd60c3ef40c28e04fc0f',
#       'width': 320},
#      {'height': 160,
#       'url': 'https://i.scdn.co/image/f696f1a38a1bc4690d398fd756fb7b7881783082',
#       'width': 160}],
#     'name': 'Marcela Gandara',
#     'popularity': 67,
#     'type': 'artist',
#     'uri': 'spotify:artist:2zF0KCQEt1O4Z9fWVUVi4T'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/4VYSLPSI9yb8qkUpKyVQSJ'},
#     'followers': {'href': None, 'total': 739879},
#     'genres': ['latin christian', 'latin worship', 'rock cristiano'],
#     'href': 'https://api.spotify.com/v1/artists/4VYSLPSI9yb8qkUpKyVQSJ',
#     'id': '4VYSLPSI9yb8qkUpKyVQSJ',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/bcb7f42c0570929e3b2c854b0ea17f1536a8d497',
#       'width': 640},
#      {'height': 320,
#       'url': 'https://i.scdn.co/image/97e6212c482da3b5533d41d2482ba4b1cf0c96db',
#       'width': 320},
#      {'height': 160,
#       'url': 'https://i.scdn.co/image/fb476dc01ce1eb968a8de94a1d2c1a4949bba0e8',
#       'width': 160}],
#     'name': 'Marco Barrientos',
#     'popularity': 66,
#     'type': 'artist',
#     'uri': 'spotify:artist:4VYSLPSI9yb8qkUpKyVQSJ'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/4x7kxyIgzgtrHYDQ8SCzo2'},
#     'followers': {'href': None, 'total': 797046},
#     'genres': ['latin christian', 'latin worship'],
#     'href': 'https://api.spotify.com/v1/artists/4x7kxyIgzgtrHYDQ8SCzo2',
#     'id': '4x7kxyIgzgtrHYDQ8SCzo2',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/c4e057b0dcdc7cbf0d0dbd14b1d1d0bc6f0656d9',
#       'width': 640},
#      {'height': 320,
#       'url': 'https://i.scdn.co/image/2eb4c343fc144cc42d7cdf9b37129730030f3883',
#       'width': 320},
#      {'height': 160,
#       'url': 'https://i.scdn.co/image/b588b45975c082832573749d978fce7ddbdf24bd',
#       'width': 160}],
#     'name': 'Marcos Witt',
#     'popularity': 66,
#     'type': 'artist',
#     'uri': 'spotify:artist:4x7kxyIgzgtrHYDQ8SCzo2'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/7AQzXO3NPNQsI7oNu5rC3r'},
#     'followers': {'href': None, 'total': 245381},
#     'genres': ['alternative rock', 'pop rock'],
#     'href': 'https://api.spotify.com/v1/artists/7AQzXO3NPNQsI7oNu5rC3r',
#     'id': '7AQzXO3NPNQsI7oNu5rC3r',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/4fdd04a01e28d2fdd7166e2d3dac4509d6fb8aa2',
#       'width': 640},
#      {'height': 320,
#       'url': 'https://i.scdn.co/image/c33da31e79e57875025973436b4253cf51dd054a',
#       'width': 320},
#      {'height': 160,
#       'url': 'https://i.scdn.co/image/431dc67b06e2140c1375d32f46760a6062029d40',
#       'width': 160}],
#     'name': 'Marcy Playground',
#     'popularity': 57,
#     'type': 'artist',
#     'uri': 'spotify:artist:7AQzXO3NPNQsI7oNu5rC3r'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/3nZ3ed6p4CKc1McTLypr6H'},
#     'followers': {'href': None, 'total': 134125},
#     'genres': ['ambient'],
#     'href': 'https://api.spotify.com/v1/artists/3nZ3ed6p4CKc1McTLypr6H',
#     'id': '3nZ3ed6p4CKc1McTLypr6H',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/1e94b8135e29bdd24b21ae4dd487b318ef4f0901',
#       'width': 640},
#      {'height': 320,
#       'url': 'https://i.scdn.co/image/c2cd3cd2f9e879c759fd6cca7644cc7ea54ba07c',
#       'width': 320},
#      {'height': 160,
#       'url': 'https://i.scdn.co/image/342ab9dae62cda1399cbba5825bba699f93d5413',
#       'width': 160}],
#     'name': 'Marconi Union',
#     'popularity': 60,
#     'type': 'artist',
#     'uri': 'spotify:artist:3nZ3ed6p4CKc1McTLypr6H'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/6JzWgxi0nFzcHq7cqpGbiz'},
#     'followers': {'href': None, 'total': 4373},
#     'genres': ['german dance'],
#     'href': 'https://api.spotify.com/v1/artists/6JzWgxi0nFzcHq7cqpGbiz',
#     'id': '6JzWgxi0nFzcHq7cqpGbiz',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/cf9509aec2dd2195c3ba6f526d64643b220700b5',
#       'width': 640},
#      {'height': 320,
#       'url': 'https://i.scdn.co/image/4433639fee7948362383f984ebc1943c818e6813',
#       'width': 320},
#      {'height': 160,
#       'url': 'https://i.scdn.co/image/a7f49233a3235280182d78bac568d6d189c78b54',
#       'width': 160}],
#     'name': 'Marcus Layton',
#     'popularity': 67,
#     'type': 'artist',
#     'uri': 'spotify:artist:6JzWgxi0nFzcHq7cqpGbiz'}],
#   'limit': 10,
#   'next': 'https://api.spotify.com/v1/search?query=Marc&type=artist&market=US&offset=10&limit=10',
#   'offset': 0,
#   'previous': None,
#   'total': 10004}}

# %% [markdown]
# ## Actividades mostradas en clase de Platzi

# %%
import pandas as pd
df = pd.DataFrame(response_search.json()['artists'])
df
# pero en realidad, la información que quiero son los items.
# Ahí es donde pueden verse los distintos artistas
# Out:
#                                                 href  ...  total
# 0  https://api.spotify.com/v1/search?query=Marc&t...  ...  10004
# 1  https://api.spotify.com/v1/search?query=Marc&t...  ...  10004
# 2  https://api.spotify.com/v1/search?query=Marc&t...  ...  10004
# 3  https://api.spotify.com/v1/search?query=Marc&t...  ...  10004
# 4  https://api.spotify.com/v1/search?query=Marc&t...  ...  10004
# 5  https://api.spotify.com/v1/search?query=Marc&t...  ...  10004
# 6  https://api.spotify.com/v1/search?query=Marc&t...  ...  10004
# 7  https://api.spotify.com/v1/search?query=Marc&t...  ...  10004
# 8  https://api.spotify.com/v1/search?query=Marc&t...  ...  10004
# 9  https://api.spotify.com/v1/search?query=Marc&t...  ...  10004
#
# [10 rows x 7 columns]

# %%
df = pd.DataFrame(response_search.json()['artists']['items'])
df.sort_values(by = 'popularity', ascending=False)
# Out:
#                                        external_urls  ...                                    uri
# 2  {'spotify': 'https://open.spotify.com/artist/4...  ...  spotify:artist:4wLXwxDeWQ8mtUIRPxGiD6
# 3  {'spotify': 'https://open.spotify.com/artist/3...  ...  spotify:artist:3tJnB0s6c3oXPq1SCCavnd
# 1  {'spotify': 'https://open.spotify.com/artist/4...  ...  spotify:artist:44mEtidu0VdRkIqO4IbkNa
# 0  {'spotify': 'https://open.spotify.com/artist/3...  ...  spotify:artist:3tQx1LPXbsYjE9VwN1Peaa
# 4  {'spotify': 'https://open.spotify.com/artist/2...  ...  spotify:artist:2zF0KCQEt1O4Z9fWVUVi4T
# 9  {'spotify': 'https://open.spotify.com/artist/6...  ...  spotify:artist:6JzWgxi0nFzcHq7cqpGbiz
# 5  {'spotify': 'https://open.spotify.com/artist/4...  ...  spotify:artist:4VYSLPSI9yb8qkUpKyVQSJ
# 6  {'spotify': 'https://open.spotify.com/artist/4...  ...  spotify:artist:4x7kxyIgzgtrHYDQ8SCzo2
# 8  {'spotify': 'https://open.spotify.com/artist/3...  ...  spotify:artist:3nZ3ed6p4CKc1McTLypr6H
# 7  {'spotify': 'https://open.spotify.com/artist/7...  ...  spotify:artist:7AQzXO3NPNQsI7oNu5rC3r
#
# [10 rows x 10 columns]

# %%
# me quedo con el primero
# df.sort_values(by = 'popularity', ascending=False).iloc[0]
df.sort_values(by = 'popularity', ascending=False).iloc[0]['id']
# Out:
# '4wLXwxDeWQ8mtUIRPxGiD6'

# %% [markdown]
# En este punto de la clase, el profesor presenta un método alternativo de obtener el código que parece más sencillo que el que yo utilicé y no requiere sólo de una librería avanzada

# %%
import base64
import json
import requests
import pandas as pd

client_id  = 'a1f9ce70491b4fbdbc386ca497a663d3'
client_secret = 'e6425613aca649ffac840e84dbd62800'

# %%
def get_token(client_id, client_secret):
  encoded = base64.b64encode(bytes(client_id+':'+client_secret, 'utf-8'))
  params = {'grant_type': 'client_credentials'}
  header = {'Authorization': 'Basic ' + str(encoded, 'utf-8')}
  r = requests.post('https://accounts.spotify.com/api/token', headers=header, data=params)
  # lo bueno de este método es que me permite validar si todo está bien
  if r.status_code != 200:
    print('Error en la request. ', r.json())
    return None
  print('Token válido por {} segundos.'.format(r.json()['expires_in']))
  return r.json()['access_token']

# %%
token = get_token(client_id,client_secret)
token
# Out:
# Token válido por 3600 segundos.
# 'BQAqYQbnn3Ax18Ja9EEGkEXAsas5C91vszEo6SaNlVITCCNekuZiA1_IxagHSomuEd2Yve0uW-_zvqPb-uw'

# %% [markdown]
# **Ahora si, vamos a obtener la discografía de Marc Anthony**

# %%
#id de marc anthony
marc_id='4wLXwxDeWQ8mtUIRPxGiD6'

# %%
url_discography = f'https://api.spotify.com/v1/artists/{marc_id}/albums'
url_discography
# Out:
# 'https://api.spotify.com/v1/artists/4wLXwxDeWQ8mtUIRPxGiD6/albums'

# %%
header = {'Authorization': 'Bearer {}'.format(token)}
params = {'country': 'US'}
albums_ma = requests.get(url_discography, headers=header, params=params)
albums_ma.json()
# Out:
# {'href': 'https://api.spotify.com/v1/artists/4wLXwxDeWQ8mtUIRPxGiD6/albums?offset=0&limit=20&include_groups=album,single,compilation,appears_on&market=US',
#  'items': [{'album_group': 'album',
#    'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4wLXwxDeWQ8mtUIRPxGiD6'},
#      'href': 'https://api.spotify.com/v1/artists/4wLXwxDeWQ8mtUIRPxGiD6',
#      'id': '4wLXwxDeWQ8mtUIRPxGiD6',
#      'name': 'Marc Anthony',
#      'type': 'artist',
#      'uri': 'spotify:artist:4wLXwxDeWQ8mtUIRPxGiD6'}],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/0iSDto0c8PqIKtwrYS4lbh'},
#    'href': 'https://api.spotify.com/v1/albums/0iSDto0c8PqIKtwrYS4lbh',
#    'id': '0iSDto0c8PqIKtwrYS4lbh',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273fd1928ea81cd2d2af3f1d1a1',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02fd1928ea81cd2d2af3f1d1a1',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851fd1928ea81cd2d2af3f1d1a1',
#      'width': 64}],
#    'name': 'OPUS',
#    'release_date': '2019-05-10',
#    'release_date_precision': 'day',
#    'total_tracks': 10,
#    'type': 'album',
#    'uri': 'spotify:album:0iSDto0c8PqIKtwrYS4lbh'},
#   {'album_group': 'album',
#    'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4wLXwxDeWQ8mtUIRPxGiD6'},
#      'href': 'https://api.spotify.com/v1/artists/4wLXwxDeWQ8mtUIRPxGiD6',
#      'id': '4wLXwxDeWQ8mtUIRPxGiD6',
#      'name': 'Marc Anthony',
#      'type': 'artist',
#      'uri': 'spotify:artist:4wLXwxDeWQ8mtUIRPxGiD6'}],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/39swduCY4gVIwMm09udx4Z'},
#    'href': 'https://api.spotify.com/v1/albums/39swduCY4gVIwMm09udx4Z',
#    'id': '39swduCY4gVIwMm09udx4Z',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273aabb3142a322848947ef7c48',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02aabb3142a322848947ef7c48',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851aabb3142a322848947ef7c48',
#      'width': 64}],
#    'name': '2En1',
#    'release_date': '2017-01-20',
#    'release_date_precision': 'day',
#    'total_tracks': 16,
#    'type': 'album',
#    'uri': 'spotify:album:39swduCY4gVIwMm09udx4Z'},
#   {'album_group': 'album',
#    'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4wLXwxDeWQ8mtUIRPxGiD6'},
#      'href': 'https://api.spotify.com/v1/artists/4wLXwxDeWQ8mtUIRPxGiD6',
#      'id': '4wLXwxDeWQ8mtUIRPxGiD6',
#      'name': 'Marc Anthony',
#      'type': 'artist',
#      'uri': 'spotify:artist:4wLXwxDeWQ8mtUIRPxGiD6'}],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/6vBpLg3T8bojcqzoKI6m0R'},
#    'href': 'https://api.spotify.com/v1/albums/6vBpLg3T8bojcqzoKI6m0R',
#    'id': '6vBpLg3T8bojcqzoKI6m0R',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b27321be16e998effa9f1f4b63a9',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e0221be16e998effa9f1f4b63a9',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d0000485121be16e998effa9f1f4b63a9',
#      'width': 64}],
#    'name': '3.0',
#    'release_date': '2013-07-23',
#    'release_date_precision': 'day',
#    'total_tracks': 10,
#    'type': 'album',
#    'uri': 'spotify:album:6vBpLg3T8bojcqzoKI6m0R'},
#   {'album_group': 'album',
#    'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4wLXwxDeWQ8mtUIRPxGiD6'},
#      'href': 'https://api.spotify.com/v1/artists/4wLXwxDeWQ8mtUIRPxGiD6',
#      'id': '4wLXwxDeWQ8mtUIRPxGiD6',
#      'name': 'Marc Anthony',
#      'type': 'artist',
#      'uri': 'spotify:artist:4wLXwxDeWQ8mtUIRPxGiD6'}],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/5SGUCNeCuGHbR73Iyh2F7g'},
#    'href': 'https://api.spotify.com/v1/albums/5SGUCNeCuGHbR73Iyh2F7g',
#    'id': '5SGUCNeCuGHbR73Iyh2F7g',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2733a890b5659a9f6dc89f618eb',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e023a890b5659a9f6dc89f618eb',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048513a890b5659a9f6dc89f618eb',
#      'width': 64}],
#    'name': 'Iconos',
#    'release_date': '2010-05-24',
#    'release_date_precision': 'day',
#    'total_tracks': 10,
#    'type': 'album',
#    'uri': 'spotify:album:5SGUCNeCuGHbR73Iyh2F7g'},
#   {'album_group': 'album',
#    'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4wLXwxDeWQ8mtUIRPxGiD6'},
#      'href': 'https://api.spotify.com/v1/artists/4wLXwxDeWQ8mtUIRPxGiD6',
#      'id': '4wLXwxDeWQ8mtUIRPxGiD6',
#      'name': 'Marc Anthony',
#      'type': 'artist',
#      'uri': 'spotify:artist:4wLXwxDeWQ8mtUIRPxGiD6'}],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/4MRdW6rlNSqpnCAZKGxqLC'},
#    'href': 'https://api.spotify.com/v1/albums/4MRdW6rlNSqpnCAZKGxqLC',
#    'id': '4MRdW6rlNSqpnCAZKGxqLC',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2731972660c2ccfe8eb3959657d',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e021972660c2ccfe8eb3959657d',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048511972660c2ccfe8eb3959657d',
#      'width': 64}],
#    'name': 'Marc Anthony "El Cantante" OST',
#    'release_date': '2007-07-24',
#    'release_date_precision': 'day',
#    'total_tracks': 10,
#    'type': 'album',
#    'uri': 'spotify:album:4MRdW6rlNSqpnCAZKGxqLC'},
#   {'album_group': 'album',
#    'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4wLXwxDeWQ8mtUIRPxGiD6'},
#      'href': 'https://api.spotify.com/v1/artists/4wLXwxDeWQ8mtUIRPxGiD6',
#      'id': '4wLXwxDeWQ8mtUIRPxGiD6',
#      'name': 'Marc Anthony',
#      'type': 'artist',
#      'uri': 'spotify:artist:4wLXwxDeWQ8mtUIRPxGiD6'}],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/70XO7jxoVIV9p9IFyjXGvJ'},
#    'href': 'https://api.spotify.com/v1/albums/70XO7jxoVIV9p9IFyjXGvJ',
#    'id': '70XO7jxoVIV9p9IFyjXGvJ',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2735b808619dac962e9df490acd',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e025b808619dac962e9df490acd',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048515b808619dac962e9df490acd',
#      'width': 64}],
#    'name': 'Sigo Siendo Yo',
#    'release_date': '2006-06-30',
#    'release_date_precision': 'day',
#    'total_tracks': 14,
#    'type': 'album',
#    'uri': 'spotify:album:70XO7jxoVIV9p9IFyjXGvJ'},
#   {'album_group': 'album',
#    'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4wLXwxDeWQ8mtUIRPxGiD6'},
#      'href': 'https://api.spotify.com/v1/artists/4wLXwxDeWQ8mtUIRPxGiD6',
#      'id': '4wLXwxDeWQ8mtUIRPxGiD6',
#      'name': 'Marc Anthony',
#      'type': 'artist',
#      'uri': 'spotify:artist:4wLXwxDeWQ8mtUIRPxGiD6'}],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/5d7Tr9DguGh9z9oByKWYoI'},
#    'href': 'https://api.spotify.com/v1/albums/5d7Tr9DguGh9z9oByKWYoI',
#    'id': '5d7Tr9DguGh9z9oByKWYoI',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b27321d0c402231babb2d979c4f5',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e0221d0c402231babb2d979c4f5',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d0000485121d0c402231babb2d979c4f5',
#      'width': 64}],
#    'name': 'Desde Un Principio / From The Beginning',
#    'release_date': '2006-01-01',
#    'release_date_precision': 'day',
#    'total_tracks': 15,
#    'type': 'album',
#    'uri': 'spotify:album:5d7Tr9DguGh9z9oByKWYoI'},
#   {'album_group': 'album',
#    'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4wLXwxDeWQ8mtUIRPxGiD6'},
#      'href': 'https://api.spotify.com/v1/artists/4wLXwxDeWQ8mtUIRPxGiD6',
#      'id': '4wLXwxDeWQ8mtUIRPxGiD6',
#      'name': 'Marc Anthony',
#      'type': 'artist',
#      'uri': 'spotify:artist:4wLXwxDeWQ8mtUIRPxGiD6'}],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/4O3yvEN5II2yKWKBPtDLD7'},
#    'href': 'https://api.spotify.com/v1/albums/4O3yvEN5II2yKWKBPtDLD7',
#    'id': '4O3yvEN5II2yKWKBPtDLD7',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273ac1b009b3ad89a504b927acf',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02ac1b009b3ad89a504b927acf',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851ac1b009b3ad89a504b927acf',
#      'width': 64}],
#    'name': 'Valio La Pena',
#    'release_date': '2004-07-27',
#    'release_date_precision': 'day',
#    'total_tracks': 8,
#    'type': 'album',
#    'uri': 'spotify:album:4O3yvEN5II2yKWKBPtDLD7'},
#   {'album_group': 'album',
#    'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4wLXwxDeWQ8mtUIRPxGiD6'},
#      'href': 'https://api.spotify.com/v1/artists/4wLXwxDeWQ8mtUIRPxGiD6',
#      'id': '4wLXwxDeWQ8mtUIRPxGiD6',
#      'name': 'Marc Anthony',
#      'type': 'artist',
#      'uri': 'spotify:artist:4wLXwxDeWQ8mtUIRPxGiD6'}],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/3MKpH3rMkzXgX5JLWeIvrq'},
#    'href': 'https://api.spotify.com/v1/albums/3MKpH3rMkzXgX5JLWeIvrq',
#    'id': '3MKpH3rMkzXgX5JLWeIvrq',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273aa7da6f38ade089ddbc0940c',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02aa7da6f38ade089ddbc0940c',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851aa7da6f38ade089ddbc0940c',
#      'width': 64}],
#    'name': 'Amar Sin Mentiras',
#    'release_date': '2004',
#    'release_date_precision': 'year',
#    'total_tracks': 10,
#    'type': 'album',
#    'uri': 'spotify:album:3MKpH3rMkzXgX5JLWeIvrq'},
#   {'album_group': 'album',
#    'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4wLXwxDeWQ8mtUIRPxGiD6'},
#      'href': 'https://api.spotify.com/v1/artists/4wLXwxDeWQ8mtUIRPxGiD6',
#      'id': '4wLXwxDeWQ8mtUIRPxGiD6',
#      'name': 'Marc Anthony',
#      'type': 'artist',
#      'uri': 'spotify:artist:4wLXwxDeWQ8mtUIRPxGiD6'}],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/3JKA2HqHrFgIhfJU7sceSe'},
#    'href': 'https://api.spotify.com/v1/albums/3JKA2HqHrFgIhfJU7sceSe',
#    'id': '3JKA2HqHrFgIhfJU7sceSe',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273432253774ff8467f619dec84',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02432253774ff8467f619dec84',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851432253774ff8467f619dec84',
#      'width': 64}],
#    'name': 'Exitos Eternos',
#    'release_date': '2003-01-01',
#    'release_date_precision': 'day',
#    'total_tracks': 14,
#    'type': 'album',
#    'uri': 'spotify:album:3JKA2HqHrFgIhfJU7sceSe'},
#   {'album_group': 'album',
#    'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4wLXwxDeWQ8mtUIRPxGiD6'},
#      'href': 'https://api.spotify.com/v1/artists/4wLXwxDeWQ8mtUIRPxGiD6',
#      'id': '4wLXwxDeWQ8mtUIRPxGiD6',
#      'name': 'Marc Anthony',
#      'type': 'artist',
#      'uri': 'spotify:artist:4wLXwxDeWQ8mtUIRPxGiD6'}],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/3M2ZwIvJqD79g1xoMu99Lm'},
#    'href': 'https://api.spotify.com/v1/albums/3M2ZwIvJqD79g1xoMu99Lm',
#    'id': '3M2ZwIvJqD79g1xoMu99Lm',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273b71efdcb94da9c1bbfa77f25',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02b71efdcb94da9c1bbfa77f25',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851b71efdcb94da9c1bbfa77f25',
#      'width': 64}],
#    'name': 'Mended',
#    'release_date': '2002-05-21',
#    'release_date_precision': 'day',
#    'total_tracks': 13,
#    'type': 'album',
#    'uri': 'spotify:album:3M2ZwIvJqD79g1xoMu99Lm'},
#   {'album_group': 'album',
#    'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4wLXwxDeWQ8mtUIRPxGiD6'},
#      'href': 'https://api.spotify.com/v1/artists/4wLXwxDeWQ8mtUIRPxGiD6',
#      'id': '4wLXwxDeWQ8mtUIRPxGiD6',
#      'name': 'Marc Anthony',
#      'type': 'artist',
#      'uri': 'spotify:artist:4wLXwxDeWQ8mtUIRPxGiD6'}],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/5ODq74kSUgWq9uLc6OWVLU'},
#    'href': 'https://api.spotify.com/v1/albums/5ODq74kSUgWq9uLc6OWVLU',
#    'id': '5ODq74kSUgWq9uLc6OWVLU',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273feee4f5691c5f36dd58f4a73',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02feee4f5691c5f36dd58f4a73',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851feee4f5691c5f36dd58f4a73',
#      'width': 64}],
#    'name': 'Libre',
#    'release_date': '2001-11-20',
#    'release_date_precision': 'day',
#    'total_tracks': 9,
#    'type': 'album',
#    'uri': 'spotify:album:5ODq74kSUgWq9uLc6OWVLU'},
#   {'album_group': 'album',
#    'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4wLXwxDeWQ8mtUIRPxGiD6'},
#      'href': 'https://api.spotify.com/v1/artists/4wLXwxDeWQ8mtUIRPxGiD6',
#      'id': '4wLXwxDeWQ8mtUIRPxGiD6',
#      'name': 'Marc Anthony',
#      'type': 'artist',
#      'uri': 'spotify:artist:4wLXwxDeWQ8mtUIRPxGiD6'}],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/4YhTaDbd74ky1z95wtuGLT'},
#    'href': 'https://api.spotify.com/v1/albums/4YhTaDbd74ky1z95wtuGLT',
#    'id': '4YhTaDbd74ky1z95wtuGLT',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273af6ed014bb566083b2235c49',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02af6ed014bb566083b2235c49',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851af6ed014bb566083b2235c49',
#      'width': 64}],
#    'name': 'The Cali Sessions',
#    'release_date': '2001',
#    'release_date_precision': 'year',
#    'total_tracks': 13,
#    'type': 'album',
#    'uri': 'spotify:album:4YhTaDbd74ky1z95wtuGLT'},
#   {'album_group': 'album',
#    'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4wLXwxDeWQ8mtUIRPxGiD6'},
#      'href': 'https://api.spotify.com/v1/artists/4wLXwxDeWQ8mtUIRPxGiD6',
#      'id': '4wLXwxDeWQ8mtUIRPxGiD6',
#      'name': 'Marc Anthony',
#      'type': 'artist',
#      'uri': 'spotify:artist:4wLXwxDeWQ8mtUIRPxGiD6'}],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/2zG5uEJ1zY00uN6qXjPu5d'},
#    'href': 'https://api.spotify.com/v1/albums/2zG5uEJ1zY00uN6qXjPu5d',
#    'id': '2zG5uEJ1zY00uN6qXjPu5d',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273427f8620c555ad3da3f50629',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02427f8620c555ad3da3f50629',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851427f8620c555ad3da3f50629',
#      'width': 64}],
#    'name': 'Marc Anthony',
#    'release_date': '1999-09-28',
#    'release_date_precision': 'day',
#    'total_tracks': 15,
#    'type': 'album',
#    'uri': 'spotify:album:2zG5uEJ1zY00uN6qXjPu5d'},
#   {'album_group': 'album',
#    'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4wLXwxDeWQ8mtUIRPxGiD6'},
#      'href': 'https://api.spotify.com/v1/artists/4wLXwxDeWQ8mtUIRPxGiD6',
#      'id': '4wLXwxDeWQ8mtUIRPxGiD6',
#      'name': 'Marc Anthony',
#      'type': 'artist',
#      'uri': 'spotify:artist:4wLXwxDeWQ8mtUIRPxGiD6'}],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/6LIqj7VIJB3K54NBycFxSe'},
#    'href': 'https://api.spotify.com/v1/albums/6LIqj7VIJB3K54NBycFxSe',
#    'id': '6LIqj7VIJB3K54NBycFxSe',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2731dff9c7ceebb43b8fbbd4885',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e021dff9c7ceebb43b8fbbd4885',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048511dff9c7ceebb43b8fbbd4885',
#      'width': 64}],
#    'name': 'Contra La Corriente',
#    'release_date': '1997-01-01',
#    'release_date_precision': 'day',
#    'total_tracks': 9,
#    'type': 'album',
#    'uri': 'spotify:album:6LIqj7VIJB3K54NBycFxSe'},
#   {'album_group': 'album',
#    'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4wLXwxDeWQ8mtUIRPxGiD6'},
#      'href': 'https://api.spotify.com/v1/artists/4wLXwxDeWQ8mtUIRPxGiD6',
#      'id': '4wLXwxDeWQ8mtUIRPxGiD6',
#      'name': 'Marc Anthony',
#      'type': 'artist',
#      'uri': 'spotify:artist:4wLXwxDeWQ8mtUIRPxGiD6'}],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/69lnF2K07sZMRbyGSuggFk'},
#    'href': 'https://api.spotify.com/v1/albums/69lnF2K07sZMRbyGSuggFk',
#    'id': '69lnF2K07sZMRbyGSuggFk',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273857bac47e8bb8305a805c065',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02857bac47e8bb8305a805c065',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851857bac47e8bb8305a805c065',
#      'width': 64}],
#    'name': 'Todo A Su Tiempo',
#    'release_date': '1995-01-01',
#    'release_date_precision': 'day',
#    'total_tracks': 9,
#    'type': 'album',
#    'uri': 'spotify:album:69lnF2K07sZMRbyGSuggFk'},
#   {'album_group': 'album',
#    'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4wLXwxDeWQ8mtUIRPxGiD6'},
#      'href': 'https://api.spotify.com/v1/artists/4wLXwxDeWQ8mtUIRPxGiD6',
#      'id': '4wLXwxDeWQ8mtUIRPxGiD6',
#      'name': 'Marc Anthony',
#      'type': 'artist',
#      'uri': 'spotify:artist:4wLXwxDeWQ8mtUIRPxGiD6'}],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/4NiUxGgt2iSsbRa6Nf2ocq'},
#    'href': 'https://api.spotify.com/v1/albums/4NiUxGgt2iSsbRa6Nf2ocq',
#    'id': '4NiUxGgt2iSsbRa6Nf2ocq',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273dfb487075aad3514bfd2769c',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02dfb487075aad3514bfd2769c',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851dfb487075aad3514bfd2769c',
#      'width': 64}],
#    'name': 'Otra Nota',
#    'release_date': '1993-01-01',
#    'release_date_precision': 'day',
#    'total_tracks': 8,
#    'type': 'album',
#    'uri': 'spotify:album:4NiUxGgt2iSsbRa6Nf2ocq'},
#   {'album_group': 'album',
#    'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5dncbrnveDMX9DgxcedeUg'},
#      'href': 'https://api.spotify.com/v1/artists/5dncbrnveDMX9DgxcedeUg',
#      'id': '5dncbrnveDMX9DgxcedeUg',
#      'name': 'Louie Vega',
#      'type': 'artist',
#      'uri': 'spotify:artist:5dncbrnveDMX9DgxcedeUg'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/4wLXwxDeWQ8mtUIRPxGiD6'},
#      'href': 'https://api.spotify.com/v1/artists/4wLXwxDeWQ8mtUIRPxGiD6',
#      'id': '4wLXwxDeWQ8mtUIRPxGiD6',
#      'name': 'Marc Anthony',
#      'type': 'artist',
#      'uri': 'spotify:artist:4wLXwxDeWQ8mtUIRPxGiD6'}],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/1NPWUPiIOPIpVDsJSUBODq'},
#    'href': 'https://api.spotify.com/v1/albums/1NPWUPiIOPIpVDsJSUBODq',
#    'id': '1NPWUPiIOPIpVDsJSUBODq',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b27372def07d75abfcc2fff5c13c',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e0272def07d75abfcc2fff5c13c',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d0000485172def07d75abfcc2fff5c13c',
#      'width': 64}],
#    'name': 'When The Night Is Over',
#    'release_date': '1991-08-02',
#    'release_date_precision': 'day',
#    'total_tracks': 11,
#    'type': 'album',
#    'uri': 'spotify:album:1NPWUPiIOPIpVDsJSUBODq'},
#   {'album_group': 'album',
#    'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5dncbrnveDMX9DgxcedeUg'},
#      'href': 'https://api.spotify.com/v1/artists/5dncbrnveDMX9DgxcedeUg',
#      'id': '5dncbrnveDMX9DgxcedeUg',
#      'name': 'Louie Vega',
#      'type': 'artist',
#      'uri': 'spotify:artist:5dncbrnveDMX9DgxcedeUg'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/4wLXwxDeWQ8mtUIRPxGiD6'},
#      'href': 'https://api.spotify.com/v1/artists/4wLXwxDeWQ8mtUIRPxGiD6',
#      'id': '4wLXwxDeWQ8mtUIRPxGiD6',
#      'name': 'Marc Anthony',
#      'type': 'artist',
#      'uri': 'spotify:artist:4wLXwxDeWQ8mtUIRPxGiD6'}],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/1sYujauyFSyYfBfDg2ImPA'},
#    'href': 'https://api.spotify.com/v1/albums/1sYujauyFSyYfBfDg2ImPA',
#    'id': '1sYujauyFSyYfBfDg2ImPA',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273726a077af10b162796155af9',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02726a077af10b162796155af9',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851726a077af10b162796155af9',
#      'width': 64}],
#    'name': 'When The Night Is Over',
#    'release_date': '1991',
#    'release_date_precision': 'year',
#    'total_tracks': 11,
#    'type': 'album',
#    'uri': 'spotify:album:1sYujauyFSyYfBfDg2ImPA'},
#   {'album_group': 'single',
#    'album_type': 'single',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4wLXwxDeWQ8mtUIRPxGiD6'},
#      'href': 'https://api.spotify.com/v1/artists/4wLXwxDeWQ8mtUIRPxGiD6',
#      'id': '4wLXwxDeWQ8mtUIRPxGiD6',
#      'name': 'Marc Anthony',
#      'type': 'artist',
#      'uri': 'spotify:artist:4wLXwxDeWQ8mtUIRPxGiD6'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/41qil2VaGbD194gaEcmmyx'},
#      'href': 'https://api.spotify.com/v1/artists/41qil2VaGbD194gaEcmmyx',
#      'id': '41qil2VaGbD194gaEcmmyx',
#      'name': 'Will Smith',
#      'type': 'artist',
#      'uri': 'spotify:artist:41qil2VaGbD194gaEcmmyx'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/4q3ewBCX7sLwd24euuV69X'},
#      'href': 'https://api.spotify.com/v1/artists/4q3ewBCX7sLwd24euuV69X',
#      'id': '4q3ewBCX7sLwd24euuV69X',
#      'name': 'Bad Bunny',
#      'type': 'artist',
#      'uri': 'spotify:artist:4q3ewBCX7sLwd24euuV69X'}],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/3ztJAikTd2AHTixfSPG185'},
#    'href': 'https://api.spotify.com/v1/albums/3ztJAikTd2AHTixfSPG185',
#    'id': '3ztJAikTd2AHTixfSPG185',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2738080569f37bbe04f68301f23',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e028080569f37bbe04f68301f23',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048518080569f37bbe04f68301f23',
#      'width': 64}],
#    'name': 'Está Rico',
#    'release_date': '2018-09-28',
#    'release_date_precision': 'day',
#    'total_tracks': 1,
#    'type': 'album',
#    'uri': 'spotify:album:3ztJAikTd2AHTixfSPG185'}],
#  'limit': 20,
#  'next': 'https://api.spotify.com/v1/artists/4wLXwxDeWQ8mtUIRPxGiD6/albums?offset=20&limit=20&include_groups=album,single,compilation,appears_on&market=US',
#  'offset': 0,
#  'previous': None,
#  'total': 564}

# %%
df_ma = pd.DataFrame(albums_ma.json()['items'])
list(df_ma)
# Out:
# ['album_group',
#  'album_type',
#  'artists',
#  'external_urls',
#  'href',
#  'id',
#  'images',
#  'name',
#  'release_date',
#  'release_date_precision',
#  'total_tracks',
#  'type',
#  'uri']

# %%
id_album_artist = df_ma['id']
id_album_artist
# Out:
# 0     0iSDto0c8PqIKtwrYS4lbh
# 1     39swduCY4gVIwMm09udx4Z
# 2     6vBpLg3T8bojcqzoKI6m0R
# 3     5SGUCNeCuGHbR73Iyh2F7g
# 4     4MRdW6rlNSqpnCAZKGxqLC
# 5     7vAvh5KAMBz324wybwqxYG
# 6     70XO7jxoVIV9p9IFyjXGvJ
# 7     3H53wpof8NX4O4TA8kppHl
# 8     4O3yvEN5II2yKWKBPtDLD7
# 9     3XaSD1CwXpIPyqWZGrF3SI
# 10    6QFmMhTV7SE1iwTHbiPeqv
# 11    3MKpH3rMkzXgX5JLWeIvrq
# 12    3JKA2HqHrFgIhfJU7sceSe
# 13    7dKqUfHdPGN5VhKbeKeT2m
# 14    3M2ZwIvJqD79g1xoMu99Lm
# 15    0bfUO1BzQ00eTOxx0t3ryK
# 16    5ODq74kSUgWq9uLc6OWVLU
# 17    3njZnLWeOsbhN9Et9FaIx5
# 18    2AjLPcC2z3K38hDYRbKAab
# 19    4Nyp7QrPLKUKeck9MIkO1q
# Name: id, dtype: object

# %%
#vamos a hacer una función que me
id = '0iSDto0c8PqIKtwrYS4lbh'
url_album = f'https://api.spotify.com/v1/albums/{id}' 
# hacemos la solicitud
header = {'Authorization': 'Bearer {}'.format(token)}
params = {'market': 'AR', 'limit':1}
album = requests.get(url_album, headers=header, params=params)
album.json()
# Out:
# {'album_type': 'album',
#  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4wLXwxDeWQ8mtUIRPxGiD6'},
#    'href': 'https://api.spotify.com/v1/artists/4wLXwxDeWQ8mtUIRPxGiD6',
#    'id': '4wLXwxDeWQ8mtUIRPxGiD6',
#    'name': 'Marc Anthony',
#    'type': 'artist',
#    'uri': 'spotify:artist:4wLXwxDeWQ8mtUIRPxGiD6'}],
#  'copyrights': [{'text': '(P) 2019 Sony Music Entertainment US Latin LLC',
#    'type': 'P'}],
#  'external_ids': {'upc': '886447616277'},
#  'external_urls': {'spotify': 'https://open.spotify.com/album/0iSDto0c8PqIKtwrYS4lbh'},
#  'genres': [],
#  'href': 'https://api.spotify.com/v1/albums/0iSDto0c8PqIKtwrYS4lbh',
#  'id': '0iSDto0c8PqIKtwrYS4lbh',
#  'images': [{'height': 640,
#    'url': 'https://i.scdn.co/image/ab67616d0000b273fd1928ea81cd2d2af3f1d1a1',
#    'width': 640},
#   {'height': 300,
#    'url': 'https://i.scdn.co/image/ab67616d00001e02fd1928ea81cd2d2af3f1d1a1',
#    'width': 300},
#   {'height': 64,
#    'url': 'https://i.scdn.co/image/ab67616d00004851fd1928ea81cd2d2af3f1d1a1',
#    'width': 64}],
#  'label': 'Sony Music Latin',
#  'name': 'OPUS',
#  'popularity': 71,
#  'release_date': '2019-05-10',
#  'release_date_precision': 'day',
#  'total_tracks': 10,
#  'tracks': {'href': 'https://api.spotify.com/v1/albums/0iSDto0c8PqIKtwrYS4lbh/tracks?offset=0&limit=50&market=AR',
#   'items': [{'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4wLXwxDeWQ8mtUIRPxGiD6'},
#       'href': 'https://api.spotify.com/v1/artists/4wLXwxDeWQ8mtUIRPxGiD6',
#       'id': '4wLXwxDeWQ8mtUIRPxGiD6',
#       'name': 'Marc Anthony',
#       'type': 'artist',
#       'uri': 'spotify:artist:4wLXwxDeWQ8mtUIRPxGiD6'}],
#     'disc_number': 1,
#     'duration_ms': 268440,
#     'explicit': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0dqfl4l45vqw2TnNrnbsy0'},
#     'href': 'https://api.spotify.com/v1/tracks/0dqfl4l45vqw2TnNrnbsy0',
#     'id': '0dqfl4l45vqw2TnNrnbsy0',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Parecen Viernes',
#     'preview_url': 'https://p.scdn.co/mp3-preview/87d72b1b0f4ce767f1e68112414ff1ca7a41bc5f?cid=a1f9ce70491b4fbdbc386ca497a663d3',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:0dqfl4l45vqw2TnNrnbsy0'},
#    {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4wLXwxDeWQ8mtUIRPxGiD6'},
#       'href': 'https://api.spotify.com/v1/artists/4wLXwxDeWQ8mtUIRPxGiD6',
#       'id': '4wLXwxDeWQ8mtUIRPxGiD6',
#       'name': 'Marc Anthony',
#       'type': 'artist',
#       'uri': 'spotify:artist:4wLXwxDeWQ8mtUIRPxGiD6'}],
#     'disc_number': 1,
#     'duration_ms': 374053,
#     'explicit': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4jzPGm9YsNvFvpL5as5DVc'},
#     'href': 'https://api.spotify.com/v1/tracks/4jzPGm9YsNvFvpL5as5DVc',
#     'id': '4jzPGm9YsNvFvpL5as5DVc',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Tu Vida en la Mía',
#     'preview_url': 'https://p.scdn.co/mp3-preview/34af1b2e82c941fc5e483d5bceb108b84c912603?cid=a1f9ce70491b4fbdbc386ca497a663d3',
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:4jzPGm9YsNvFvpL5as5DVc'},
#    {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4wLXwxDeWQ8mtUIRPxGiD6'},
#       'href': 'https://api.spotify.com/v1/artists/4wLXwxDeWQ8mtUIRPxGiD6',
#       'id': '4wLXwxDeWQ8mtUIRPxGiD6',
#       'name': 'Marc Anthony',
#       'type': 'artist',
#       'uri': 'spotify:artist:4wLXwxDeWQ8mtUIRPxGiD6'}],
#     'disc_number': 1,
#     'duration_ms': 258640,
#     'explicit': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3Wx05XUK4VGLYWTChk572f'},
#     'href': 'https://api.spotify.com/v1/tracks/3Wx05XUK4VGLYWTChk572f',
#     'id': '3Wx05XUK4VGLYWTChk572f',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Un Amor Eterno',
#     'preview_url': 'https://p.scdn.co/mp3-preview/e13d08350de494586d03a0a8793b92dabbb0fb32?cid=a1f9ce70491b4fbdbc386ca497a663d3',
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:3Wx05XUK4VGLYWTChk572f'},
#    {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4wLXwxDeWQ8mtUIRPxGiD6'},
#       'href': 'https://api.spotify.com/v1/artists/4wLXwxDeWQ8mtUIRPxGiD6',
#       'id': '4wLXwxDeWQ8mtUIRPxGiD6',
#       'name': 'Marc Anthony',
#       'type': 'artist',
#       'uri': 'spotify:artist:4wLXwxDeWQ8mtUIRPxGiD6'}],
#     'disc_number': 1,
#     'duration_ms': 269746,
#     'explicit': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6bOQdhEjkS8FS6XcNKEA8T'},
#     'href': 'https://api.spotify.com/v1/tracks/6bOQdhEjkS8FS6XcNKEA8T',
#     'id': '6bOQdhEjkS8FS6XcNKEA8T',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Si Me Creyeras',
#     'preview_url': 'https://p.scdn.co/mp3-preview/4bc49052a10535a2c4c23639e19452dc2d7855e1?cid=a1f9ce70491b4fbdbc386ca497a663d3',
#     'track_number': 4,
#     'type': 'track',
#     'uri': 'spotify:track:6bOQdhEjkS8FS6XcNKEA8T'},
#    {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4wLXwxDeWQ8mtUIRPxGiD6'},
#       'href': 'https://api.spotify.com/v1/artists/4wLXwxDeWQ8mtUIRPxGiD6',
#       'id': '4wLXwxDeWQ8mtUIRPxGiD6',
#       'name': 'Marc Anthony',
#       'type': 'artist',
#       'uri': 'spotify:artist:4wLXwxDeWQ8mtUIRPxGiD6'}],
#     'disc_number': 1,
#     'duration_ms': 290520,
#     'explicit': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1siATRpCTikt3dpJiBonfk'},
#     'href': 'https://api.spotify.com/v1/tracks/1siATRpCTikt3dpJiBonfk',
#     'id': '1siATRpCTikt3dpJiBonfk',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Soy Yo',
#     'preview_url': 'https://p.scdn.co/mp3-preview/93b87a75b262cc4701315f5ea24b5de308e67e2a?cid=a1f9ce70491b4fbdbc386ca497a663d3',
#     'track_number': 5,
#     'type': 'track',
#     'uri': 'spotify:track:1siATRpCTikt3dpJiBonfk'},
#    {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4wLXwxDeWQ8mtUIRPxGiD6'},
#       'href': 'https://api.spotify.com/v1/artists/4wLXwxDeWQ8mtUIRPxGiD6',
#       'id': '4wLXwxDeWQ8mtUIRPxGiD6',
#       'name': 'Marc Anthony',
#       'type': 'artist',
#       'uri': 'spotify:artist:4wLXwxDeWQ8mtUIRPxGiD6'}],
#     'disc_number': 1,
#     'duration_ms': 241760,
#     'explicit': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0W8NvcMsIuygeFnfNz2KnC'},
#     'href': 'https://api.spotify.com/v1/tracks/0W8NvcMsIuygeFnfNz2KnC',
#     'id': '0W8NvcMsIuygeFnfNz2KnC',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Lo Que Te Di',
#     'preview_url': 'https://p.scdn.co/mp3-preview/1e7b1830ebba62dd52c04432f2692d3ef488c307?cid=a1f9ce70491b4fbdbc386ca497a663d3',
#     'track_number': 6,
#     'type': 'track',
#     'uri': 'spotify:track:0W8NvcMsIuygeFnfNz2KnC'},
#    {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4wLXwxDeWQ8mtUIRPxGiD6'},
#       'href': 'https://api.spotify.com/v1/artists/4wLXwxDeWQ8mtUIRPxGiD6',
#       'id': '4wLXwxDeWQ8mtUIRPxGiD6',
#       'name': 'Marc Anthony',
#       'type': 'artist',
#       'uri': 'spotify:artist:4wLXwxDeWQ8mtUIRPxGiD6'}],
#     'disc_number': 1,
#     'duration_ms': 299880,
#     'explicit': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4mOJzarE7lW4dXOkoKYJD2'},
#     'href': 'https://api.spotify.com/v1/tracks/4mOJzarE7lW4dXOkoKYJD2',
#     'id': '4mOJzarE7lW4dXOkoKYJD2',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Úsame',
#     'preview_url': 'https://p.scdn.co/mp3-preview/886b545000d05a32c86546dd0023873ea6e681e6?cid=a1f9ce70491b4fbdbc386ca497a663d3',
#     'track_number': 7,
#     'type': 'track',
#     'uri': 'spotify:track:4mOJzarE7lW4dXOkoKYJD2'},
#    {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4wLXwxDeWQ8mtUIRPxGiD6'},
#       'href': 'https://api.spotify.com/v1/artists/4wLXwxDeWQ8mtUIRPxGiD6',
#       'id': '4wLXwxDeWQ8mtUIRPxGiD6',
#       'name': 'Marc Anthony',
#       'type': 'artist',
#       'uri': 'spotify:artist:4wLXwxDeWQ8mtUIRPxGiD6'}],
#     'disc_number': 1,
#     'duration_ms': 266253,
#     'explicit': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/23288B0A1kT4rAJj208j23'},
#     'href': 'https://api.spotify.com/v1/tracks/23288B0A1kT4rAJj208j23',
#     'id': '23288B0A1kT4rAJj208j23',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Si Pudiera',
#     'preview_url': 'https://p.scdn.co/mp3-preview/559c7a8a0d7a859a71539d0c509183352f661ed4?cid=a1f9ce70491b4fbdbc386ca497a663d3',
#     'track_number': 8,
#     'type': 'track',
#     'uri': 'spotify:track:23288B0A1kT4rAJj208j23'},
#    {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4wLXwxDeWQ8mtUIRPxGiD6'},
#       'href': 'https://api.spotify.com/v1/artists/4wLXwxDeWQ8mtUIRPxGiD6',
#       'id': '4wLXwxDeWQ8mtUIRPxGiD6',
#       'name': 'Marc Anthony',
#       'type': 'artist',
#       'uri': 'spotify:artist:4wLXwxDeWQ8mtUIRPxGiD6'}],
#     'disc_number': 1,
#     'duration_ms': 310186,
#     'explicit': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7iXdo6hpRStLGnV6ZbSzEE'},
#     'href': 'https://api.spotify.com/v1/tracks/7iXdo6hpRStLGnV6ZbSzEE',
#     'id': '7iXdo6hpRStLGnV6ZbSzEE',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Lo Peor de Mí',
#     'preview_url': 'https://p.scdn.co/mp3-preview/24269dd0105223e13dd7af1b6b7ee8822adf8725?cid=a1f9ce70491b4fbdbc386ca497a663d3',
#     'track_number': 9,
#     'type': 'track',
#     'uri': 'spotify:track:7iXdo6hpRStLGnV6ZbSzEE'},
#    {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4wLXwxDeWQ8mtUIRPxGiD6'},
#       'href': 'https://api.spotify.com/v1/artists/4wLXwxDeWQ8mtUIRPxGiD6',
#       'id': '4wLXwxDeWQ8mtUIRPxGiD6',
#       'name': 'Marc Anthony',
#       'type': 'artist',
#       'uri': 'spotify:artist:4wLXwxDeWQ8mtUIRPxGiD6'}],
#     'disc_number': 1,
#     'duration_ms': 250026,
#     'explicit': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0aG17biAmgU7qiExo3gYkt'},
#     'href': 'https://api.spotify.com/v1/tracks/0aG17biAmgU7qiExo3gYkt',
#     'id': '0aG17biAmgU7qiExo3gYkt',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Reconozco',
#     'preview_url': 'https://p.scdn.co/mp3-preview/f3adc2bf79b8ddf45caa0cfc8132df1d7e63b6eb?cid=a1f9ce70491b4fbdbc386ca497a663d3',
#     'track_number': 10,
#     'type': 'track',
#     'uri': 'spotify:track:0aG17biAmgU7qiExo3gYkt'}],
#   'limit': 50,
#   'next': None,
#   'offset': 0,
#   'previous': None,
#   'total': 10},
#  'type': 'album',
#  'uri': 'spotify:album:0iSDto0c8PqIKtwrYS4lbh'}

# %%
#album.json()['id']
album.json()['name']
# Out:
# 'OPUS'

# %%
# construimos una función que nos regrese el ID y el nombre del album
'''def get_discography(artist_id, token, market='AR'):
  url_discography = f'https://api.spotify.com/v1/artists/{artist_id}/albums'
  header = {'Authorization': 'Bearer {}'.format(token)}
  params = {'country': market}
  albums_list = requests.get(url_discography, headers=header, params=params)
  if albums_list.status_code != 200:
    print(f'HTTP requests for artist discography has an error. Status Code {album_list.status_code} ')f
    break
  
  df_albums = pd.DataFrame(albums_ma.json()['items'])
  id_album_artist = df_albums['id'] 

  # con la lista construida ahora vamos a extraer la información de cada 
'''
# STOP STOP STOP STOP STOP

# %% [markdown]
# Me volví un culo, estaba utilizando DF y otras cosas cuando podía hacerlo más facil

# %%
list_albums = [(album['id'], album['name']) for album in albums_ma.json()['items']]
list_albums
# Out:
# [('0iSDto0c8PqIKtwrYS4lbh', 'OPUS'),
#  ('39swduCY4gVIwMm09udx4Z', '2En1'),
#  ('6vBpLg3T8bojcqzoKI6m0R', '3.0'),
#  ('5SGUCNeCuGHbR73Iyh2F7g', 'Iconos'),
#  ('4MRdW6rlNSqpnCAZKGxqLC', 'Marc Anthony "El Cantante" OST'),
#  ('70XO7jxoVIV9p9IFyjXGvJ', 'Sigo Siendo Yo'),
#  ('5d7Tr9DguGh9z9oByKWYoI', 'Desde Un Principio / From The Beginning'),
#  ('4O3yvEN5II2yKWKBPtDLD7', 'Valio La Pena'),
#  ('3MKpH3rMkzXgX5JLWeIvrq', 'Amar Sin Mentiras'),
#  ('3JKA2HqHrFgIhfJU7sceSe', 'Exitos Eternos'),
#  ('3M2ZwIvJqD79g1xoMu99Lm', 'Mended'),
#  ('5ODq74kSUgWq9uLc6OWVLU', 'Libre'),
#  ('4YhTaDbd74ky1z95wtuGLT', 'The Cali Sessions'),
#  ('2zG5uEJ1zY00uN6qXjPu5d', 'Marc Anthony'),
#  ('6LIqj7VIJB3K54NBycFxSe', 'Contra La Corriente'),
#  ('69lnF2K07sZMRbyGSuggFk', 'Todo A Su Tiempo'),
#  ('4NiUxGgt2iSsbRa6Nf2ocq', 'Otra Nota'),
#  ('1NPWUPiIOPIpVDsJSUBODq', 'When The Night Is Over'),
#  ('1sYujauyFSyYfBfDg2ImPA', 'When The Night Is Over'),
#  ('3ztJAikTd2AHTixfSPG185', 'Está Rico')]

# %% [markdown]
# Ahora vamos a armar una función para obtener la discografía completa

# %%
def obtener_discografía( artist_id, token, return_name = False, page_limit = 50,  country = 'US' ):
  url_discography = f'https://api.spotify.com/v1/artists/{artist_id}/albums'
  header = {'Authorization': f'Bearer {token}'}
  params = {'country': country, 'limit': page_limit, 'offset': 0}

  resultados = [] #armo una lista vacía donde se guardan todos los resultados
  r = requests.get(url_discography, headers=header, params=params)

  if r.status_code != 200:
    print('Error en la request.', r.json())
    return None
  
  if return_name:
    resultados += [(album['id'], album['name']) for album in r.json()['items']]
  else:
    resultados += [album['id'] for album in r.json()['items']]

  # tenemos que extraer todo los nombre de los albums para eso utilizaremos la URL 
  # que aparece la llame next
  while r.json()['next']:
    # sobrescribimos
    r = requests.get(r.json()['next'], headers=header)
    
    if return_name:
      resultados += [(album['id'], album['name']) for album in r.json()['items']]
    else:
      resultados += [album['id'] for album in r.json()['items']]

  return resultados

# %%
token = get_token(client_id,client_secret)
# Out:
# Token válido por 3600 segundos.

# %%
artist_id = '1uiEZYehlNivdK3iQyAbye' # tom misch
obtener_discografía(artist_id, token, return_name=True)
# Out:
# [('6iOCv7oGL5sGi2aVnRz2BI', 'What Kinda Music'),
#  ('28enuddLPEA914scE6Drvk', 'Geography'),
#  ('5IW5ko3B1W5doRD3YH9DV8', 'Beat Tape 2'),
#  ('2FVfODkF1inBzSwB2plsYk', 'Beat Tape 1'),
#  ('2xNZKNIlHUY9NKXrHzr19g', 'What Kinda Music (Jordan Rakei Remix)'),
#  ('4u5C68CzGi223ErII6MD3l', 'Nightrider'),
#  ('3lsbLyfaGRdwKX3EROHyoV', 'Kyiv'),
#  ('3nOTv7wBRQ4bxeeIw47a6l', 'Lift Off'),
#  ('7rnlxqdiSjjvceJLVMMmmv', 'What Kinda Music'),
#  ('1nJJZh7fy1gS36zRDRbu4k', 'My Fancy Free Future Love (Tom Misch Remix)'),
#  ('5qmEF78Uq9CjwIgvKQe7WG', 'Money'),
#  ('3OGqx2jmVKVkKOIOxGjOQC', 'Lost in Paris'),
#  ('5xwjUoVyZTxDN0P9D2GXFd', 'It Runs Through Me'),
#  ('1eG8nI5TfqmhLPur9OxpVS', 'Water Baby'),
#  ('7l6WtR1PQw7lw2K1uwd5Jv', 'Movie'),
#  ('6iPciC9NdMIedCFPw1LRhx', 'South of the River (Detroit Swindle Remix)'),
#  ('4gBMR4WEwK3PIQsgIxtlLC', 'South of the River'),
#  ('7fxmKgApcmXOVOlXuNEsQL', '5 Day Mischon'),
#  ('3WSToOVYwpErPB9T77lw7w', 'Watch Me Dance (Crackazat Remix)'),
#  ('7KiHTorahtMj9enKWtg5lo', 'Losing My Way'),
#  ('3ssz8pi55szsiCBRpJr4xV', 'Midnight Mischief (Tom Misch Remix)'),
#  ('5zAiufzCS4SXV7fHNSJPm9', 'Reverie'),
#  ('5WeI0airp8xZmmalIwKtNP', 'I Wish'),
#  ('3QaujyUDkMoPwWLF79ibGC', 'Crazy Dream'),
#  ('278C3YPG1SJGEDFGTtfNIN', 'Watch Me Dance'),
#  ('0FRzeA6Fm2qkKRZDin7edH', 'Nightgowns'),
#  ('341ISPpYAsClY0ynOSL01G', 'Wander With Me'),
#  ('0129Rd4uIQKR8b0yJc61cQ', 'Wake Up This Day'),
#  ('1Fy4vHTz1ihmgMOkcdVPV1', 'In the Midst of It All'),
#  ('75VJrhsSKG0PeL8tPofZku', 'Sunshine'),
#  ('4wp0IfsM1CHUClStCSrecA', 'Out to Sea'),
#  ('30665HqOre14GEeakTMDlG', 'So Close'),
#  ('1LGek39nwaOf4K6mNZWeG4', 'Memory'),
#  ('5SGqMgnBMC16lg0A0suMzL', 'Snowboarding Vibes'),
#  ('08QU0gcOwgdtVDtlPMITiq', 'Almost Bedtime'),
#  ('7K6uLd8u0Nz2hisJ96y6qn', 'Music For The Waiting Room'),
#  ('5IMfvld8FmfzXQP6Ln9hUN', 'Happy At Home'),
#  ('09pF9CzWsqeq0eYQZuzZj8', 'Sunday Morning Chill'),
#  ('7mSeJvfnwqKpgSw5h8qJ47', 'Hip Hop Chillout'),
#  ('08M6wSSjAnqkh1NxWC5F39', 'Chilled music 2020'),
#  ('3XkZfqOxTPyFoY0dCbcbr0', 'Chill FM'),
#  ('0esWgWPUvH76FqARbwe571', 'Indie Chill'),
#  ('1i6evjjzyuaYmYX728JwvT', 'Motivational Music for the Syncopated Soul'),
#  ('0YuUq0jT4GIpxnyrw99bJV', 'Chill Indie'),
#  ('3AvaJKMF0bMnKssRlZk7mg', 'High Life, the Remixes'),
#  ('1kokRXXxrJzhxdMo0vsVDV', 'Not Waving, But Drowning'),
#  ('5tbvov0fii1eMXkTYZmVdp',
#   'Good to Be Home (feat. Tom Misch, Loyle Carner & Rebel Kleff)'),
#  ('1GpJeoYxcez8hKdk6tforL', 'Home Is Where the Art Is'),
#  ('0fwZXPXf41aF6H0CN3UtXV', 'Love Me / Love Me Not'),
#  ('7g8pvoUtlwjwC6GKH73uRW',
#   'Defected Radio Episode 105 (hosted by Sam Divine)'),
#  ('6JMceOsAz0CRAfAnUaWgmo', 'High Life'),
#  ('3X3qGMrv9Ksj43hH3IQoy8', 'LoFi Chillhop'),
#  ('1e0blqgzgUh3rh4FjpS0Do', 'Like Butter'),
#  ('5EfAzZ6xQDgpwEfInondWI', 'Fresh Edge'),
#  ('362NzWNPfafxg12Rb4ja6j', 'Cold Little Heart (Tom Misch Remix)'),
#  ('76I01qVo4ZifEPV3XKSCmQ', 'Loosies, Vol. 2'),
#  ('6wjryxtrKxzTZID9kyZUV5', "Yesterday's Gone"),
#  ('50Ov4yZEvCvWFYF9ZMWRJA', 'Painting Sounds'),
#  ('4XhktNPie56OkdRcitrQhU', 'Stay Close'),
#  ('2C1NdT1ZhiGcLxnvBSnH2H', 'Friends (Tom Misch Remixes) (feat. Tom Morello)'),
#  ('2ezlCEYf5C0DLmAZtiUl49', 'The Remedy'),
#  ('134HP01Gf7TECy2tb4Cj1V', "What You Don't Do (Tom Misch Remix)"),
#  ('7KEhJz1ps7Ia0COtbMFoIC', 'Nocturne'),
#  ('2f7tXt1KmkXAscFZapwZUg', 'Where I’m From')]

# %%
def obtener_tracks( album_id, token, return_name = False, page_limit = 50, market = 'US' ):
  url_tracks = f'https://api.spotify.com/v1/albums/{album_id}/tracks'
  header = {'Authorization': f'Bearer {token}'}
  params = {'market': market, 'limit': page_limit, 'offset': 0}

  resultados = [] #armo una lista vacía donde se guardan todos los resultados
  r = requests.get(url_tracks, headers=header, params=params)
  
  if r.status_code != 200:
    print('Error en la request.', r.json())
    return None
  
  if return_name:
    resultados += [(track['id'], track['name']) for track in r.json()['items']]
  else:
    resultados += [track['id'] for track in r.json()['items']]

  # tenemos que extraer todo los nombre de los albums para eso utilizaremos la URL 
  # que aparece la llame next
  while r.json()['next']:
    # sobrescribimos
    r = requests.get(r.json()['next'], headers=header)
    
    if return_name:
      resultados += [(track['id'], track['name']) for track in r.json()['items']]
    else:
      resultados += [track['id'] for track in r.json()['items']]
  
  return resultados

# %%
obtener_tracks( album_id='6iOCv7oGL5sGi2aVnRz2BI', token=token, return_name=True )
# Out:
# [('47w6S27JF4Zvrz1Wd6R66Z', 'What Kinda Music'),
#  ('2lXFtsU8naRn2mC0DACJEl', 'Festival'),
#  ('5TgZ7lOUugOdabBcD9a6ud', 'Nightrider'),
#  ('4Goj7amQLl2PiPYaiB0VlV', 'Tidal Wave'),
#  ('5oEhWt6RfUHSBiSfZVnymh', 'Sensational'),
#  ('28wERzXJWMb4Qx1bf9EXyW', 'The Real'),
#  ('6yvTddeHmEiYG7FN8a5frz', 'Lift Off'),
#  ('4xWLo3R0jjTVOdmtjC5MKI', 'I Did It For You'),
#  ('39WFZVKifA8Fl2TZI2kp0S', 'Last 100'),
#  ('1vzqTU4KJrKhezhPgZkjTr', 'Kyiv'),
#  ('7qGAPavRijMOtbm7EzCaUq', 'Julie Mangos'),
#  ('1wq5gRZ5JRn25N4JCUg1oO', 'Storm Before The Calm')]

# %% [markdown]
# Aquí juntaremos ambas funciones, para obtener el final de la función

# %%
for album in obtener_discografía(artist_id, token,return_name=True):
  print(album[1])
  for track in obtener_tracks(album[0], token, return_name=True):
    print('\t', track[1])
# Out:
# What Kinda Music
# 	 What Kinda Music
# 	 Festival
# 	 Nightrider
# 	 Tidal Wave
# 	 Sensational
# 	 The Real
# 	 Lift Off
# 	 I Did It For You
# 	 Last 100
# 	 Kyiv
# 	 Julie Mangos
# 	 Storm Before The Calm
# Geography
# 	 Before Paris
# 	 Lost in Paris
# 	 South of the River
# 	 Movie
# 	 Tick Tock
# 	 It Runs Through Me
# 	 Isn't She Lovely
# 	 Disco Yes
# 	 Man Like You
# 	 Water Baby
# 	 You're On My Mind
# 	 Cos I Love You
# 	 We've Come So Far
# Beat Tape 2
# 	 The Journey
# 	 Wander With Me
# 	 Nightgowns
# 	 Falafel
# 	 Wake Up This Day
# 	 In the Midst of It All
# 	 Come Back
# 	 Your Love
# 	 Hark
# 	 Colours of Freedom
# 	 Beautiful Escape
# 	 Home
# Beat Tape 1
# 	 The Real Thing
# 	 In a Special Way
# 	 Summer
# 	 Take Me Back
# 	 Keep Moving
# 	 Lush Lyfe
# 	 Epiphany
# 	 Dilla Love
# 	 Cruisin'
# 	 Deeper
# 	 Windmills of Your Mind
# 	 Climbing
# 	 Marrakech
# 	 Euphoric
# 	 Can't Explain It
# 	 Maguel Chops
# 	 Wind (Jazzy Joint)
# 	 Wonder
# 	 You Got Me Flying
# What Kinda Music (Jordan Rakei Remix)
# 	 What Kinda Music - Jordan Rakei Remix
# Nightrider
# 	 Nightrider
# Kyiv
# 	 Kyiv
# Lift Off
# 	 Lift Off
# What Kinda Music
# 	 What Kinda Music
# My Fancy Free Future Love (Tom Misch Remix)
# 	 My Fancy Free Future Love - Tom Misch Remix
# 	 My Fancy Free Future Love
# Money
# 	 Money (with Tom Misch)
# Lost in Paris
# 	 Lost in Paris
# It Runs Through Me
# 	 It Runs Through Me
# Water Baby
# 	 Water Baby
# Movie
# 	 Movie
# South of the River (Detroit Swindle Remix)
# 	 South of the River - Detroit Swindle Remix
# South of the River
# 	 South of the River
# 5 Day Mischon
# 	 Day 1: Ephemeral
# 	 Day 2: Feeling
# 	 Day 3: When You Want to Love
# 	 Day 4: Everybody Get Down
# 	 Day 5: For Carol
# Watch Me Dance (Crackazat Remix)
# 	 Watch Me Dance - Crackazat Remix
# Losing My Way
# 	 Losing My Way
# 	 Losing My Way - Live at O2 Academy Brixton, 2019
# Midnight Mischief (Tom Misch Remix)
# 	 Midnight Mischief - Tom Misch Remix
# Reverie
# 	 Crazy Dream
# 	 Follow
# 	 I Wish
# 	 Watch Me Dance
# I Wish
# 	 I Wish
# Crazy Dream
# 	 Crazy Dream
# Watch Me Dance
# 	 Watch Me Dance
# Nightgowns
# 	 Nightgowns
# Wander With Me
# 	 Wander With Me
# Wake Up This Day
# 	 Wake Up This Day
# In the Midst of It All
# 	 In the Midst of It All
# Sunshine
# 	 Sunshine
# Out to Sea
# 	 So Close
# 	 With You
# 	 Release You
# 	 Paper Planes
# 	 Outro
# So Close
# 	 So Close
# Memory
# 	 Memory
# Snowboarding Vibes
# 	 Intro (Donna)
# 	 Check The Technique
# 	 Fremd
# 	 Rebirth Of Slick (Cool Like Dat)
# 	 6. Dezember
# 	 Ain't Nothing Changed
# 	 Fuji
# 	 Respiration
# 	 Alles Gut
# 	 Now You're Mine
# 	 Eu E O Meu Amor
# 	 Me Or The Papes
# 	 Malibu
# 	 Moonrocks
# 	 Too Much For You
# 	 Damselfly
# 	 Egal
# 	 Steine
# 	 The Isle Of Arran
# 	 Young Blood
# 	 Work
# 	 G.R.I.N.D. (Get Ready It's A New Day)
# 	 No Cap
# 	 Habits (Stay High)
# 	 Wieso
# 	 Tennis Court
# 	 Someday
# 	 10
# Almost Bedtime
# 	 Bruises
# 	 Where We Began
# 	 Let It Go
# 	 Damselfly
# 	 In My Head
# 	 Oblivion
# 	 Wildest Ones
# 	 Talk Is Overrated
# 	 Calling
# 	 The Shine Is Brighter At Night
# 	 More Than Life
# 	 Renegades
# 	 Revolution
# 	 Youth
# 	 The Mess I Made
# 	 Breathe Me
# 	 Read All About It, Pt. III
# 	 Hold On
# 	 Wild - Acoustic Version
# 	 Mended - Acoustic
# 	 River Of Tears
# 	 Broken Strings
# 	 Only
# 	 Hey There Delilah - Bonus Track
# 	 Love Of My Life
# 	 Keep You Warm - Low Key
# 	 Idle Town
# 	 Half A Man
# 	 Almost Lover
# 	 Don't Forget About Me
# 	 You Are The Reason
# 	 St Jude
# 	 When You Love Someone
# 	 10,000 Emerald Pools
# 	 Happy Ending
# 	 'Cause I'm A Man
# 	 Dark Days
# 	 A Place That I Don’t Know
# 	 Wake The City - Acoustic
# 	 All We Do
# 	 Come Home
# 	 Sunday Night - Acoustic
# 	 Sorry
# Music For The Waiting Room
# 	 'Cause I'm A Man
# 	 10,000 Emerald Pools
# 	 Running Red Lights
# 	 Youth
# 	 The Shine Is Brighter At Night
# 	 When You Love Someone
# 	 1965
# 	 Stuck With Me
# 	 If Only You Could Ease My Mind
# 	 Eyes Shut
# 	 California
# 	 Revolution
# 	 Have You Ever Seen The Rain
# 	 ILYSB
# 	 Waiting
# 	 Oblivion
# 	 Hey There Delilah - Bonus Track
# 	 Wild - Acoustic Version
# 	 Bending Back
# 	 She Is Love - Main
# 	 You Give Me Something
# 	 Apologize
# 	 Dark Days
# 	 Glitter & Gold
# 	 Last Week
# 	 Empty
# 	 Dancing On My Own
# 	 Further Than The Planes Fly - Acoustic
# 	 Talk Is Overrated
# 	 Damselfly
# 	 Team
# 	 The End - Low Key
# 	 Mended - Acoustic
# 	 When You Sleep
# 	 River Of Tears
# 	 Nothin On My Mind
# 	 Better Now - Acoustic
# 	 Never Let Me Go
# 	 Wake The City - Acoustic
# 	 Ruin
# 	 Half A Man
# 	 My Heart Is Not A Machine
# 	 Sunday Night - Acoustic
# 	 Unconditional Love
# 	 Livewire
# Happy At Home
# 	 Stay Awake
# 	 Generation Why
# 	 Space Cowboy
# 	 Seven Hours
# 	 False Start
# 	 Youth
# 	 10,000 Emerald Pools
# 	 Headcheck
# 	 Polka
# 	 Is This How You Feel?
# 	 Turn Me On
# 	 Make You Mine
# 	 Shuffle
# 	 Ooh La
# 	 My Heart Is A Wheel
# 	 Vertigo
# 	 Cool As Hell
# 	 Selling Me Out
# 	 Waiting
# 	 All The Pretty Girls
# 	 Exit Sign
# 	 Super Far
# 	 Damselfly
# 	 Livewire
# 	 Regular Touch
# 	 Further Than The Planes Fly
# 	 Where We Began
# 	 Alaska
# 	 Hollow
# 	 Supalonely
# 	 Talk Is Overrated
# 	 How Long
# Sunday Morning Chill
# 	 Hey There Delilah
# 	 This Town
# 	 You And Me
# 	 Seven Hours
# 	 Chasing Patterns
# 	 Empty
# 	 Be Alright
# 	 Stay High - Habits Remix
# 	 September Song
# 	 Running Red Lights
# 	 Sunday Best
# 	 Drive
# 	 Turn
# 	 Therapy
# 	 Sunrise
# 	 Glitter & Gold
# 	 Breathe Deeper
# 	 Make You Mine
# 	 Slow Burn
# 	 Apologize
# 	 Further Than The Planes Fly
# 	 California
# 	 More Than Life
# 	 Dark Days
# 	 Have You Ever Seen The Rain
# 	 Youth
# 	 Cold Little Heart - Radio Edit
# 	 Better Together
# 	 Find A Way
# 	 Dog Years
# 	 Bending Back
# 	 Nothin On My Mind
# 	 Talk Is Overrated
# 	 Count It Up
# 	 Super Far
# 	 Team
# 	 10,000 Emerald Pools
# 	 Generation Why
# 	 Selling Me Out
# 	 Waiting
# 	 Bridges
# 	 West
# 	 Damselfly
# 	 Where We Began
# 	 Let It Go
# 	 Next To Me
# 	 Issues
# 	 Bruises
# 	 The Maze
# 	 Dream A Little Dream Of Me - Single Version
# 	 Don't Forget About Me
# 	 Never Let Me Go
# 	 Hands Down
# 	 If Only You Could Ease My Mind
# 	 Revolution
# 	 Treading Water
# 	 Fever To The Form
# 	 Do You Remember
# Hip Hop Chillout
# 	 Dilemma
# 	 I Need You - From the Netflix original series "Blood & Water"
# 	 Around The Way Girl
# 	 He Got Game - From The "He Got Game" Soundtrack
# 	 Mr. Wendal
# 	 Make You Feel That Way
# 	 Children's Story
# 	 Me Or The Papes
# 	 Boca Raton
# 	 Still Fly
# 	 Ms. Fat Booty
# 	 The Light
# 	 Twist My Fingaz
# 	 Sugar Hill
# 	 Cherry Wine
# 	 The Fire
# 	 Turnin' Me Up
# 	 It Was A Good Day
# 	 Passin' Me By
# 	 Express Yourself - Remix
# 	 I'll Be There For You/You're All I Need To Get By - Puff Daddy Mix
# 	 I Know You Got Soul
# 	 Let The Funk Flow
# 	 Provider
# 	 Brown Skin Lady
# 	 Jersey
# 	 Fade Away
# 	 On & On
# 	 Shadowboxin'
# 	 When I B On Tha Mic
# 	 Ain't Nothing Changed
# 	 Soul Food
# 	 Black With N V (No Vision)
# 	 Rebirth of Slick (Cool Like Dat)
# 	 Loungin'
# 	 Above The Clouds
# 	 Tonight's Da Night
# 	 Caroline
# 	 oui
# 	 Damselfly
# 	 Hey Ma
# 	 The Morning
# 	 Slim's Return
# 	 Feel It In The Air
# 	 UMI Says
# Chilled music 2020
# 	 I Won't Let You Go
# 	 All For You
# 	 Pinewood
# 	 LUV
# 	 I Do The Best I Can
# 	 Someone Else
# 	 Feels Like We Only Go Backwards
# 	 Little Sister
# 	 10,000 Emerald Pools
# 	 Summertime Blue
# 	 Alaska
# 	 Nudes
# 	 Never Let Me Go
# 	 angelina
# 	 the breakup.
# 	 Control
# 	 Glamorous
# 	 Ripples
# 	 Seven Hours
# 	 A Little Messed Up
# 	 Talk Is Overrated
# 	 Crazy Love - Ex. Soundcloud
# 	 chemicals
# 	 It Don't Matter
# 	 Keep Cool
# 	 Cold Little Heart - Radio Edit
# 	 Candy
# 	 You And Me
# 	 Lonely
# 	 Hey Laura
# 	 TIME
# 	 Golden Hour
# 	 Levitate
# 	 Sunday Morning
# 	 You've Got The Love
# 	 No More Drama
# 	 Suga Suga
# 	 oui
# 	 Bending Back
# 	 Sunrise
# 	 Damselfly
# 	 Therapy
# 	 More Than Life
# 	 Dark Days
# 	 Have You Ever Seen The Rain
# 	 Glitter & Gold
# 	 1965
# 	 Empty
# 	 Turn
# 	 Youth
# 	 West
# 	 Super Far
# 	 Nothin On My Mind
# Chill FM
# 	 Half A Man
# 	 A Place That I Don’t Know
# 	 Supalonely
# 	 Borderline - Album Edit
# 	 Telephone
# 	 Cold Little Heart - Radio Edit
# 	 Put Your Records On
# 	 Thought I Could
# 	 Like I Remember You
# 	 Free Fallin'
# 	 Sweet Pea
# 	 Selling Me Out
# 	 Peace - Acoustic
# 	 I Remember
# 	 If Only You Could Ease My Mind
# 	 Amazing
# 	 Say You Love Me - Shura Remix
# 	 You Give Me Something
# 	 Wish You Well
# 	 Find A Way
# 	 We Won't Run
# 	 Further Than The Planes Fly
# 	 September Song - Guitar Acoustic
# 	 Talk Is Overrated
# 	 Sunrise
# 	 It Don't Matter
# 	 10,000 Emerald Pools
# 	 Sunrise
# 	 The Way I Talk
# 	 Steal My Kisses
# 	 Youth
# 	 Technicolour Beat
# 	 Empty
# 	 Super Far
# 	 Have You Ever Seen The Rain
# 	 Seven Hours
# 	 Damselfly
# 	 Royals
# 	 Never Let Me Go
# 	 Issues - Acoustic
# 	 Dancing On My Own - Acoustic
# 	 Don't Forget About Me
# Indie Chill
# 	 Do You Remember
# 	 Empty
# 	 10,000 Emerald Pools
# 	 Glitter & Gold
# 	 Turn
# 	 Youth
# 	 Bridges
# 	 Super Far
# 	 Feels Like We Only Go Backwards
# 	 1965
# 	 Nothin On My Mind
# 	 Livewire
# 	 Revolution
# 	 Hands Down
# 	 Sunrise
# 	 Therapy
# 	 If Only You Could Ease My Mind
# 	 Waves
# 	 Damselfly
# 	 Bending Back
# 	 More Than Life
# 	 Never Let Me Go
# 	 Seven Hours
# 	 California
# 	 Dark Days
# 	 Talk Is Overrated
# 	 Have You Ever Seen The Rain
# Motivational Music for the Syncopated Soul
# 	 Limited World
# 	 St. Paul
# 	 Lunchtime
# 	 Cosmic Sans
# 	 Home
# 	 Today I'm Gonna Get Myself a Real Job
# 	 Starting Line
# 	 Companion Pass
# 	 Frogville
# 	 Gumshü
# Chill Indie
# 	 10,000 Emerald Pools
# 	 Do You Remember
# 	 Empty
# 	 Youth
# 	 Bridges
# 	 Heart Beats Slow
# 	 Turn
# 	 Livewire
# 	 1965
# 	 Glitter & Gold
# 	 Feels Like We Only Go Backwards
# 	 Nothin On My Mind
# 	 Alaska
# 	 Super Far
# 	 Revolution
# 	 West
# 	 Hands Down
# 	 Waiting
# 	 If Only You Could Ease My Mind
# 	 Waves
# 	 Therapy
# 	 Damselfly
# 	 Sunrise
# 	 Bending Back
# 	 Never Let Me Go
# 	 Seven Hours
# 	 California
# 	 More Than Life
# 	 Talk Is Overrated
# 	 Dark Days
# 	 Have You Ever Seen The Rain
# High Life, the Remixes
# 	 Yes, No, Maybe - Sterac Electronics Remix
# 	 Call of the Wild - Cinthie Remix
# 	 High Life - Jura Soundsystem Remix
# 	 Ketama Gold - Matt Karmil Remix
# 	 Ex Machina - Gari Romalis' Detroit On the Move Remix
# 	 Yes, No, Maybe - Sterac Electronics Instrumental Remix
# Not Waving, But Drowning
# 	 Dear Jean
# 	 Angel
# 	 Ice Water
# 	 Ottolenghi
# 	 You Don't Know
# 	 Still
# 	 It’s Coming Home?
# 	 Desoleil (Brilliant Corners)
# 	 Loose Ends
# 	 Not Waving, But Drowning
# 	 Krispy
# 	 Sail Away Freestyle
# 	 Looking Back
# 	 Carluccio
# 	 Dear Ben
# Good to Be Home (feat. Tom Misch, Loyle Carner & Rebel Kleff)
# 	 Good to Be Home (feat. Tom Misch, Loyle Carner & Rebel Kleff)
# Home Is Where the Art Is
# 	 Return of the Real
# 	 Something True
# 	 Rose Thorn
# 	 Know Him Well
# 	 Matooke (Interlude)
# 	 Apologies
# 	 It's About Time
# 	 Lullaby
# 	 Ilvu Too
# 	 LOOK AT YOUR MAN NOW!
# 	 Merchants
# 	 Home Is Where the Art Is
# 	 Breakdown Cover
# Love Me / Love Me Not
# 	 I Might ◑
# 	 Me & You ◑
# 	 Day 1 ◑
# 	 I Got You ◑
# 	 Feels So Good ◑
# 	 306 ◑
# 	 Location Unknown ◐
# 	 Crying Over You ◐
# 	 Shrink ◐
# 	 I Just Wanna Go Back ◐
# 	 Sometimes ◐
# 	 Forget Me Not ◐
# Defected Radio Episode 105 (hosted by Sam Divine)
# 	 Episode 105 Intro - Mixed
# 	 Sometimes The Going Gets A Little Tough - Mixed
# 	 Searching (feat. Jinadu) - Deetron Remix [Mixed]
# 	 Gotta Come Back - Mixed
# 	 Never Talk To Aliens - Mixed
# 	 Jockey - Mixed
# 	 Feelings - Mixed
# 	 STAY 2NITE - Mixed
# 	 Yes, No, Maybe (feat. Tom Misch) - Mixed
# 	 Prescription For Life (feat. Debbi Blackwell-Cook) - C&W Mix [Mixed]
# 	 El Sueño (feat. Martina Camargo) - Mixed
# 	 Jump - Mixed
# 	 Revolution - Deep In Jersey Mix [Mixed]
# 	 Swimming Places - Jerome Sydenham Remix [Mixed]
# High Life
# 	 Ketama Gold
# 	 High Life feat. Lorenz Rhode
# 	 Call of the Wild feat. Jungle by Night
# 	 Yes, No, Maybe feat. Tom Misch
# 	 The Girl from Shiraz
# 	 Flavourism feat. Seven Davis Jr.
# 	 Freeqy Polly
# 	 Ex Machina
# 	 Cut U Loose
# 	 Lucky Number 13
# LoFi Chillhop
# 	 FEEL.
# 	 changes
# 	 Reason (& Metro Boomin)
# 	 Neighbors
# 	 Smoke.Netflix.Chill.
# 	 if i could i would feel nothing
# 	 The Guide
# 	 Violence (feat. Masego)
# 	 Friends To Lovers
# 	 Clap Your Hands - MUTO Remix
# 	 Damselfly
# 	 Love Me Right
# 	 Kno Ya Wrong
# 	 Paralyzed
# 	 Sunshine
# Like Butter
# 	 Turnin' Me Up
# 	 Me and Your Mama
# 	 After The Storm (feat. Tyler, The Creator & Bootsy Collins)
# 	 Jennifer
# 	 Living Single
# 	 Destiny N Stereo
# 	 Night Drive
# 	 Anita
# 	 Premonition (feat. Earthgang & Cam O'bi)
# 	 Power
# 	 All The Way
# 	 Violence (feat. Masego)
# 	 Queen
# 	 Feels Good - XamVolo Remix
# 	 STREET LIVIN'
# 	 Angels / Your Love
# 	 Say I Didn't
# 	 THROWYOASSOUT
# 	 These Walls
# 	 Brown Sugar - Incognito Molasses Mix
# 	 Like A Woman
# 	 Drip
# 	 Bad Boys Need Love Too
# 	 Kissing Tree
# 	 Damselfly
# 	 Swim
# 	 Fallen
# 	 Sometimes
# 	 Earth Girls
# 	 Midnight
# 	 How I Feel
# Fresh Edge
# 	 Blue Pill
# 	 On Me
# 	 Man's Not Hot
# 	 Catch Me Outside
# 	 Phone Calls
# 	 Bust Down
# 	 Skrt Skrt
# 	 New Freezer
# 	 I Don't Know You
# 	 Cookies & Sherbert
# 	 Jeeps
# 	 Trending
# 	 Way Out
# 	 Flipmode
# 	 Nobody
# 	 I Know
# 	 Pull Up Hop Out - Remix
# 	 Damselfly
# 	 Wrist Motion
# 	 Little Boy
# 	 Lurkin
# 	 Let You Down
# 	 BabyWipe
# 	 In Too Deep
# 	 Doin’ It
# 	 P.O.P.
# 	 Up Next
# 	 Dive
# 	 My Dawg
# 	 Krispy Kreme
# 	 Gamble
# Cold Little Heart (Tom Misch Remix)
# 	 Cold Little Heart - Tom Misch Remix
# Loosies, Vol. 2
# 	 2am Samba
# 	 Shine Through
# 	 One4Bug
# 	 Aneeta
# 	 Fantastic Interlude
# 	 Forever
# 	 Inbetween Times
# 	 One4Bobby
# 	 Another Journey
# 	 Victory Lap
# Yesterday's Gone
# 	 The Isle Of Arran
# 	 Mean It In The Morning
# 	 +44
# 	 Damselfly
# 	 Ain't Nothing Changed
# 	 Swear
# 	 Florence
# 	 The Seamstress (Tooting Masala)
# 	 Stars & Shards
# 	 No Worries
# 	 Rebel 101
# 	 NO CD
# 	 Mrs C
# 	 Sun Of Jean
# 	 Yesterday's Gone
# Painting Sounds
# 	 Intro
# 	 Down
# 	 Rubicon - Same Old Me
# 	 I'm Going to Tell You
# 	 Nothing Around
# 	 Leave
# 	 Beep Beep, Pt. 2
# 	 Painting
# 	 C(her)ch Interlude
# 	 Destructive Beauty
# 	 Epilogue
# 	 Stay Close
# Stay Close
# 	 Stay Close
# Friends (Tom Misch Remixes) (feat. Tom Morello)
# 	 Friends (feat. Tom Morello) - Tom Misch Remix
# 	 Friends (feat. Tom Morello) - Tom Misch Alternative Remix
# The Remedy
# 	 Prescribe You an Intro
# 	 Sour Grapes
# 	 Gone Missing
# 	 Technicrime
# 	 Elevate
# 	 Let It Breathe
# 	 Sweet Bite
# 	 Homeopathic Magic
# 	 Squidgey Black
# 	 The Sickness - Extended Version
# 	 Changing Me
# 	 Drinking Is an Art
# 	 Cloudburst
# 	 Cured?
# What You Don't Do (Tom Misch Remix)
# 	 What You Don't Do - Tom Misch Remix
# Nocturne
# 	 Intro
# 	 Answers
# 	 Blaze
# 	 What If / Interlude
# 	 No Peace
# 	 Closer
# 	 Delusions / Ruminations / Interlude
# 	 Dreams
# 	 Dreaming / Interlude
# 	 Hopeful
# 	 Sunrise - Pillows
# Where I’m From
# 	 Where I'm From
# 	 Where I'm From - I Remember How To Dub
# 	 Where I'm From - Tom Misch Remix

# %%
# vamos con el bonus! 
# buscamos el preview url de un track que te divierta
preview_url = 'https://p.scdn.co/mp3-preview/1e7b1830ebba62dd52c04432f2692d3ef488c307?cid=a1f9ce70491b4fbdbc386ca497a663d3'

# %%
preview =requests.get(preview_url)
preview
# Out:
# <Response [200]>

# %%
import IPython.display as ipd
ipd.Audio(preview.content)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
